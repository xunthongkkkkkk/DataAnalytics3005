# %% [markdown]
# Code: Use Pandas to read the CSV file and store them in a DataFrame object named badminton2.
# Next, it will display the data frame.

# %%
import pandas as pd
badminton = pd.read_csv('badmintondata.csv', header='infer')

badminton
# Out:
#        HUMAN PLAYER POSITION (X) metres  HUMAN PLAYER POSITION (Y) metres  \
# 0                                     4                                 1
# 1                                     4                                 1
# 2                                     4                                 1
# 3                                     4                                 1
# 4                                     4                                 1
# ...                                 ...                               ...
# 72795                                 0                                 0
# 72796                                 0                                 0
# 72797                                 0                                 0
# 72798                                 0                                 0
# 72799                                 0                                 0
#
#        INITITAL VELOCITY OF SHUTTELCOCK(m/s)  \
# 0                                         10
# 1                                         10
# 2                                         10
# 3                                         10
# 4                                         10
# ...                                      ...
# 72795                                      0
# 72796                                      0
# 72797                                      0
# 72798                                      0
# 72799                                      0
#
#        INITIAL SHUTTELCOCK FIRING ANGLE (DEGREE)  \
# 0                                             40
# 1                                             40
# 2                                             40
# 3                                             40
# 4                                             40
# ...                                          ...
# 72795                                          0
# 72796                                          0
# 72797                                          0
# 72798                                          0
# 72799                                          0
#
#        SHUTTELCOCK SLANT ANGLE TO SIDELINE(DEGREE)  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
# ...                                            ...
# 72795                                            0
# 72796                                            0
# 72797                                            0
# 72798                                            0
# 72799                                            0
#
#        SHUTTLECOCK POSITIION IN AIR(X ) metres  \
# 0                                     4.075543
# 1                                     4.152007
# 2                                     4.228906
# 3                                     4.302100
# 4                                     4.376877
# ...                                        ...
# 72795                                 0.000000
# 72796                                 0.000000
# 72797                                 0.000000
# 72798                                 0.000000
# 72799                                 0.000000
#
#        SHUTTLECOCK POSITIION IN AIR(Y) metres  \
# 0                                         1.0
# 1                                         1.0
# 2                                         1.0
# 3                                         1.0
# 4                                         1.0
# ...                                       ...
# 72795                                     0.0
# 72796                                     0.0
# 72797                                     0.0
# 72798                                     0.0
# 72799                                     0.0
#
#        SHUTTLECOCK POSITIION IN AIR(Z) metres
# 0                                    1.662912
# 1                                    1.724866
# 2                                    1.788139
# 3                                    1.845245
# 4                                    1.904128
# ...                                       ...
# 72795                                0.000000
# 72796                                0.000000
# 72797                                0.000000
# 72798                                0.000000
# 72799                                0.000000
#
# [72800 rows x 8 columns]

# %% [markdown]
# Check Data Types

# %%
badminton.dtypes
# Out:
# HUMAN PLAYER POSITION (X) metres                 int64
# HUMAN PLAYER POSITION (Y) metres                 int64
# INITITAL VELOCITY OF SHUTTELCOCK(m/s)            int64
# INITIAL SHUTTELCOCK FIRING ANGLE (DEGREE)        int64
# SHUTTELCOCK SLANT ANGLE TO SIDELINE(DEGREE)      int64
# SHUTTLECOCK POSITIION IN AIR(X ) metres        float64
# SHUTTLECOCK POSITIION IN AIR(Y) metres         float64
# SHUTTLECOCK POSITIION IN AIR(Z) metres         float64
# dtype: object

# %% [markdown]
# Identify if there is any Missing Data in the attributes

# %%
print(badminton.isnull().sum())
# Out:
# HUMAN PLAYER POSITION (X) metres               0
# HUMAN PLAYER POSITION (Y) metres               0
# INITITAL VELOCITY OF SHUTTELCOCK(m/s)          0
# INITIAL SHUTTELCOCK FIRING ANGLE (DEGREE)      0
# SHUTTELCOCK SLANT ANGLE TO SIDELINE(DEGREE)    0
# SHUTTLECOCK POSITIION IN AIR(X ) metres        0
# SHUTTLECOCK POSITIION IN AIR(Y) metres         0
# SHUTTLECOCK POSITIION IN AIR(Z) metres         0
# dtype: int64

# %% [markdown]
# Initialize SHOT ID to each group

# %%
# Create boolean mask if all row values are 0
mask = (badminton == 0).all(axis=1)

# Identify where the 'all zeros' condition changes
changes = mask.ne(mask.shift())

# Cumulatively sum these changes, assign SHOT_ID to each group
badminton['SHOT_ID'] = changes.cumsum()

# For 'all zero' rows, assign SHOT_ID as 0
badminton.loc[mask, 'SHOT_ID'] = 0

# %% [markdown]
# Identify Duplicate Data

# %%
# Check whether each row is a duplicate of a previous row in the table
dups = badminton.duplicated()

dups
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 72795     True
# 72796     True
# 72797     True
# 72798     True
# 72799     True
# Length: 72800, dtype: bool

# %%
duplicate = badminton[badminton.duplicated()]

duplicate
# Out:
#        HUMAN PLAYER POSITION (X) metres  HUMAN PLAYER POSITION (Y) metres  \
# 123                                   0                                 0
# 124                                   0                                 0
# 125                                   0                                 0
# 126                                   0                                 0
# 127                                   0                                 0
# ...                                 ...                               ...
# 72795                                 0                                 0
# 72796                                 0                                 0
# 72797                                 0                                 0
# 72798                                 0                                 0
# 72799                                 0                                 0
#
#        INITITAL VELOCITY OF SHUTTELCOCK(m/s)  \
# 123                                        0
# 124                                        0
# 125                                        0
# 126                                        0
# 127                                        0
# ...                                      ...
# 72795                                      0
# 72796                                      0
# 72797                                      0
# 72798                                      0
# 72799                                      0
#
#        INITIAL SHUTTELCOCK FIRING ANGLE (DEGREE)  \
# 123                                            0
# 124                                            0
# 125                                            0
# 126                                            0
# 127                                            0
# ...                                          ...
# 72795                                          0
# 72796                                          0
# 72797                                          0
# 72798                                          0
# 72799                                          0
#
#        SHUTTELCOCK SLANT ANGLE TO SIDELINE(DEGREE)  \
# 123                                              0
# 124                                              0
# 125                                              0
# 126                                              0
# 127                                              0
# ...                                            ...
# 72795                                            0
# 72796                                            0
# 72797                                            0
# 72798                                            0
# 72799                                            0
#
#        SHUTTLECOCK POSITIION IN AIR(X ) metres  \
# 123                                        0.0
# 124                                        0.0
# 125                                        0.0
# 126                                        0.0
# 127                                        0.0
# ...                                        ...
# 72795                                      0.0
# 72796                                      0.0
# 72797                                      0.0
# 72798                                      0.0
# 72799                                      0.0
#
#        SHUTTLECOCK POSITIION IN AIR(Y) metres  \
# 123                                       0.0
# 124                                       0.0
# 125                                       0.0
# 126                                       0.0
# 127                                       0.0
# ...                                       ...
# 72795                                     0.0
# 72796                                     0.0
# 72797                                     0.0
# 72798                                     0.0
# 72799                                     0.0
#
#        SHUTTLECOCK POSITIION IN AIR(Z) metres  SHOT_ID
# 123                                       0.0        0
# 124                                       0.0        0
# 125                                       0.0        0
# 126                                       0.0        0
# 127                                       0.0        0
# ...                                       ...      ...
# 72795                                     0.0        0
# 72796                                     0.0        0
# 72797                                     0.0        0
# 72798                                     0.0        0
# 72799                                     0.0        0
#
# [33641 rows x 9 columns]

# %% [markdown]
# The results suggest there are 112715 duplicate rows in the dataset.

# %%
# Drop duplicate data
print('Number of rows before discarding duplicates = %d' % (badminton.shape[0]))
data2 = badminton.drop_duplicates()
print('Number of rows after discarding duplicates = %d' % (data2.shape[0]))
# Out:
# Number of rows before discarding duplicates = 72800
# Number of rows after discarding duplicates = 39159

# %% [markdown]
# Remove rows that are all zeros

# %%
data2 = data2.loc[~(data2==0).all(axis=1)]

data2
# Out:
#        HUMAN PLAYER POSITION (X) metres  HUMAN PLAYER POSITION (Y) metres  \
# 0                                     4                                 1
# 1                                     4                                 1
# 2                                     4                                 1
# 3                                     4                                 1
# 4                                     4                                 1
# ...                                 ...                               ...
# 72634                                 4                                 4
# 72635                                 4                                 4
# 72636                                 4                                 4
# 72637                                 4                                 4
# 72638                                 4                                 4
#
#        INITITAL VELOCITY OF SHUTTELCOCK(m/s)  \
# 0                                         10
# 1                                         10
# 2                                         10
# 3                                         10
# 4                                         10
# ...                                      ...
# 72634                                     70
# 72635                                     70
# 72636                                     70
# 72637                                     70
# 72638                                     70
#
#        INITIAL SHUTTELCOCK FIRING ANGLE (DEGREE)  \
# 0                                             40
# 1                                             40
# 2                                             40
# 3                                             40
# 4                                             40
# ...                                          ...
# 72634                                         70
# 72635                                         70
# 72636                                         70
# 72637                                         70
# 72638                                         70
#
#        SHUTTELCOCK SLANT ANGLE TO SIDELINE(DEGREE)  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
# ...                                            ...
# 72634                                           15
# 72635                                           15
# 72636                                           15
# 72637                                           15
# 72638                                           15
#
#        SHUTTLECOCK POSITIION IN AIR(X ) metres  \
# 0                                     4.075543
# 1                                     4.152007
# 2                                     4.228906
# 3                                     4.302100
# 4                                     4.376877
# ...                                        ...
# 72634                                 9.217823
# 72635                                 9.275177
# 72636                                 9.326363
# 72637                                 9.370879
# 72638                                 9.412822
#
#        SHUTTLECOCK POSITIION IN AIR(Y) metres  \
# 0                                    1.000000
# 1                                    1.000000
# 2                                    1.000000
# 3                                    1.000000
# 4                                    1.000000
# ...                                       ...
# 72634                                5.398111
# 72635                                5.413480
# 72636                                5.427195
# 72637                                5.439123
# 72638                                5.450361
#
#        SHUTTLECOCK POSITIION IN AIR(Z) metres  SHOT_ID
# 0                                    1.662912        1
# 1                                    1.724866        1
# 2                                    1.788139        1
# 3                                    1.845245        1
# 4                                    1.904128        1
# ...                                       ...      ...
# 72634                                2.591053      727
# 72635                                2.041410      727
# 72636                                1.463594      727
# 72637                                0.862842      727
# 72638                                0.230964      727
#
# [39158 rows x 9 columns]

# %% [markdown]
# Remove abnormal values (Value is Negative or Value = 0)

# %%
data2 = data2[(data2[data2.columns] >= 0).all(axis=1)]

data2
# Out:
#        HUMAN PLAYER POSITION (X) metres  HUMAN PLAYER POSITION (Y) metres  \
# 0                                     4                                 1
# 1                                     4                                 1
# 2                                     4                                 1
# 3                                     4                                 1
# 4                                     4                                 1
# ...                                 ...                               ...
# 72634                                 4                                 4
# 72635                                 4                                 4
# 72636                                 4                                 4
# 72637                                 4                                 4
# 72638                                 4                                 4
#
#        INITITAL VELOCITY OF SHUTTELCOCK(m/s)  \
# 0                                         10
# 1                                         10
# 2                                         10
# 3                                         10
# 4                                         10
# ...                                      ...
# 72634                                     70
# 72635                                     70
# 72636                                     70
# 72637                                     70
# 72638                                     70
#
#        INITIAL SHUTTELCOCK FIRING ANGLE (DEGREE)  \
# 0                                             40
# 1                                             40
# 2                                             40
# 3                                             40
# 4                                             40
# ...                                          ...
# 72634                                         70
# 72635                                         70
# 72636                                         70
# 72637                                         70
# 72638                                         70
#
#        SHUTTELCOCK SLANT ANGLE TO SIDELINE(DEGREE)  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
# ...                                            ...
# 72634                                           15
# 72635                                           15
# 72636                                           15
# 72637                                           15
# 72638                                           15
#
#        SHUTTLECOCK POSITIION IN AIR(X ) metres  \
# 0                                     4.075543
# 1                                     4.152007
# 2                                     4.228906
# 3                                     4.302100
# 4                                     4.376877
# ...                                        ...
# 72634                                 9.217823
# 72635                                 9.275177
# 72636                                 9.326363
# 72637                                 9.370879
# 72638                                 9.412822
#
#        SHUTTLECOCK POSITIION IN AIR(Y) metres  \
# 0                                    1.000000
# 1                                    1.000000
# 2                                    1.000000
# 3                                    1.000000
# 4                                    1.000000
# ...                                       ...
# 72634                                5.398111
# 72635                                5.413480
# 72636                                5.427195
# 72637                                5.439123
# 72638                                5.450361
#
#        SHUTTLECOCK POSITIION IN AIR(Z) metres  SHOT_ID
# 0                                    1.662912        1
# 1                                    1.724866        1
# 2                                    1.788139        1
# 3                                    1.845245        1
# 4                                    1.904128        1
# ...                                       ...      ...
# 72634                                2.591053      727
# 72635                                2.041410      727
# 72636                                1.463594      727
# 72637                                0.862842      727
# 72638                                0.230964      727
#
# [39158 rows x 9 columns]

# %%
# Calculate Q1, Q3, and IQR
Q1 = data2.iloc[:, 1:].groupby(data2['SHOT_ID']).quantile(0.25)  # Group by SHOT_ID
Q3 = data2.iloc[:, 1:].groupby(data2['SHOT_ID']).quantile(0.75)  # Group by SHOT_ID
IQR = Q3 - Q1

# Duplicate the original dataframe for use in the next steps
df_temp = data2.copy()

# Calculate outlier mask for each row
for shot_id in data2['SHOT_ID'].unique():
    outlier_mask = ((df_temp[df_temp['SHOT_ID'] == shot_id].iloc[:, 1:] < (Q1.loc[shot_id] - 1.5 * IQR.loc[shot_id])) | 
                    (df_temp[df_temp['SHOT_ID'] == shot_id].iloc[:, 1:] > (Q3.loc[shot_id] + 1.5 * IQR.loc[shot_id]))).any(axis=1)
    df_temp.loc[df_temp['SHOT_ID'] == shot_id, 'outlier_mask'] = outlier_mask

# Identify outlier SHOT_IDs
outlier_shot_ids = df_temp[df_temp['outlier_mask']].SHOT_ID.unique()

# Filter out outliers by SHOT_ID
df_no_outliers = df_temp[~df_temp['SHOT_ID'].isin(outlier_shot_ids)].drop(columns='outlier_mask')

# Calculate and print number of rows removed
removed_rows_outliers = data2.shape[0] - df_no_outliers.shape[0]
print(f"\nData after removing outliers: (removed {removed_rows_outliers} rows)")

# Update data2 to df_no_outliers
data2 = df_no_outliers
data2
# Out:
# C:\Users\xunth\AppData\Local\Temp\ipykernel_13348\1900504282.py:11: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outlier_mask = ((df_temp[df_temp['SHOT_ID'] == shot_id].iloc[:, 1:] < (Q1.loc[shot_id] - 1.5 * IQR.loc[shot_id])) |
# C:\Users\xunth\AppData\Local\Temp\ipykernel_13348\1900504282.py:12: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   (df_temp[df_temp['SHOT_ID'] == shot_id].iloc[:, 1:] > (Q3.loc[shot_id] + 1.5 * IQR.loc[shot_id]))).any(axis=1)
# Data after removing outliers: (removed 11468 rows)
#        HUMAN PLAYER POSITION (X) metres  HUMAN PLAYER POSITION (Y) metres  \
# 18800                                 4                                 1
# 18801                                 4                                 1
# 18802                                 4                                 1
# 18803                                 4                                 1
# 18804                                 4                                 1
# ...                                 ...                               ...
# 72634                                 4                                 4
# 72635                                 4                                 4
# 72636                                 4                                 4
# 72637                                 4                                 4
# 72638                                 4                                 4
#
#        INITITAL VELOCITY OF SHUTTELCOCK(m/s)  \
# 18800                                     10
# 18801                                     10
# 18802                                     10
# 18803                                     10
# 18804                                     10
# ...                                      ...
# 72634                                     70
# 72635                                     70
# 72636                                     70
# 72637                                     70
# 72638                                     70
#
#        INITIAL SHUTTELCOCK FIRING ANGLE (DEGREE)  \
# 18800                                         60
# 18801                                         60
# 18802                                         60
# 18803                                         60
# 18804                                         60
# ...                                          ...
# 72634                                         70
# 72635                                         70
# 72636                                         70
# 72637                                         70
# 72638                                         70
#
#        SHUTTELCOCK SLANT ANGLE TO SIDELINE(DEGREE)  \
# 18800                                            0
# 18801                                            0
# 18802                                            0
# 18803                                            0
# 18804                                            0
# ...                                            ...
# 72634                                           15
# 72635                                           15
# 72636                                           15
# 72637                                           15
# 72638                                           15
#
#        SHUTTLECOCK POSITIION IN AIR(X ) metres  \
# 18800                                 4.049659
# 18801                                 4.100141
# 18802                                 4.147209
# 18803                                 4.197915
# 18804                                 4.246229
# ...                                        ...
# 72634                                 9.217823
# 72635                                 9.275177
# 72636                                 9.326363
# 72637                                 9.370879
# 72638                                 9.412822
#
#        SHUTTLECOCK POSITIION IN AIR(Y) metres  \
# 18800                                1.000000
# 18801                                1.000000
# 18802                                1.000000
# 18803                                1.000000
# 18804                                1.000000
# ...                                       ...
# 72634                                5.398111
# 72635                                5.413480
# 72636                                5.427195
# 72637                                5.439123
# 72638                                5.450361
#
#        SHUTTLECOCK POSITIION IN AIR(Z) metres  SHOT_ID
# 18800                                1.685961      189
# 18801                                1.770894      189
# 18802                                1.852351      189
# 18803                                1.935086      189
# 18804                                2.013513      189
# ...                                       ...      ...
# 72634                                2.591053      727
# 72635                                2.041410      727
# 72636                                1.463594      727
# 72637                                0.862842      727
# 72638                                0.230964      727
#
# [27690 rows x 9 columns]

# %% [markdown]
# Check data that is served out of court

# %%
import numpy as np

# Define court dimensions
court_length = 13.4  # in metres
court_width = 5.18  # in metres

# Initialize 'OUT_OF_COURT_SHOTS' column
data2 = data2.assign(OUT_OF_COURT_SHOTS = np.nan)

# Assign values to 'OUT_OF_COURT_SHOTS' column
data2['OUT_OF_COURT_SHOTS'] = np.where((data2['SHUTTLECOCK POSITIION IN AIR(X ) metres'] > court_length) | 
                                     (data2['SHUTTLECOCK POSITIION IN AIR(Y) metres'] > court_width), 0, 1)

# Count the number of 'IN' and 'OUT' rows
in_court = data2['OUT_OF_COURT_SHOTS'].sum()
out_of_court = data2.shape[0] - in_court

print(f"Number of 'IN' rows: {in_court}")
print(f"Number of 'OUT' rows: {out_of_court}")
data2
# Out:
# Number of 'IN' rows: 27070
# Number of 'OUT' rows: 620
#        HUMAN PLAYER POSITION (X) metres  HUMAN PLAYER POSITION (Y) metres  \
# 18800                                 4                                 1
# 18801                                 4                                 1
# 18802                                 4                                 1
# 18803                                 4                                 1
# 18804                                 4                                 1
# ...                                 ...                               ...
# 72634                                 4                                 4
# 72635                                 4                                 4
# 72636                                 4                                 4
# 72637                                 4                                 4
# 72638                                 4                                 4
#
#        INITITAL VELOCITY OF SHUTTELCOCK(m/s)  \
# 18800                                     10
# 18801                                     10
# 18802                                     10
# 18803                                     10
# 18804                                     10
# ...                                      ...
# 72634                                     70
# 72635                                     70
# 72636                                     70
# 72637                                     70
# 72638                                     70
#
#        INITIAL SHUTTELCOCK FIRING ANGLE (DEGREE)  \
# 18800                                         60
# 18801                                         60
# 18802                                         60
# 18803                                         60
# 18804                                         60
# ...                                          ...
# 72634                                         70
# 72635                                         70
# 72636                                         70
# 72637                                         70
# 72638                                         70
#
#        SHUTTELCOCK SLANT ANGLE TO SIDELINE(DEGREE)  \
# 18800                                            0
# 18801                                            0
# 18802                                            0
# 18803                                            0
# 18804                                            0
# ...                                            ...
# 72634                                           15
# 72635                                           15
# 72636                                           15
# 72637                                           15
# 72638                                           15
#
#        SHUTTLECOCK POSITIION IN AIR(X ) metres  \
# 18800                                 4.049659
# 18801                                 4.100141
# 18802                                 4.147209
# 18803                                 4.197915
# 18804                                 4.246229
# ...                                        ...
# 72634                                 9.217823
# 72635                                 9.275177
# 72636                                 9.326363
# 72637                                 9.370879
# 72638                                 9.412822
#
#        SHUTTLECOCK POSITIION IN AIR(Y) metres  \
# 18800                                1.000000
# 18801                                1.000000
# 18802                                1.000000
# 18803                                1.000000
# 18804                                1.000000
# ...                                       ...
# 72634                                5.398111
# 72635                                5.413480
# 72636                                5.427195
# 72637                                5.439123
# 72638                                5.450361
#
#        SHUTTLECOCK POSITIION IN AIR(Z) metres  SHOT_ID  OUT_OF_COURT_SHOTS
# 18800                                1.685961      189                   1
# 18801                                1.770894      189                   1
# 18802                                1.852351      189                   1
# 18803                                1.935086      189                   1
# 18804                                2.013513      189                   1
# ...                                       ...      ...                 ...
# 72634                                2.591053      727                   0
# 72635                                2.041410      727                   0
# 72636                                1.463594      727                   0
# 72637                                0.862842      727                   0
# 72638                                0.230964      727                   0
#
# [27690 rows x 10 columns]

# %% [markdown]
# Re-number SHOT_ID after removed abnormal data rows

# %%
# Create sorted list of unique shotIds
shotIds = sorted(data2['SHOT_ID'].unique())

# Map old shotIds to new shotIds
map_dict = {old_id: new_id for new_id, old_id in enumerate(shotIds, start=1)}

# Replace old shotIds with new shotIds
data2.loc[:, 'SHOT_ID'] = data2['SHOT_ID'].replace(map_dict)

# Reorder columns
data2 = data2[['SHOT_ID', 'HUMAN PLAYER POSITION (X) metres', 'HUMAN PLAYER POSITION (Y) metres',
         'INITITAL VELOCITY OF SHUTTELCOCK(m/s)', 'INITIAL SHUTTELCOCK FIRING ANGLE (DEGREE)',
         'SHUTTELCOCK SLANT ANGLE TO SIDELINE(DEGREE)', 'SHUTTLECOCK POSITIION IN AIR(X ) metres',
         'SHUTTLECOCK POSITIION IN AIR(Y) metres', 'SHUTTLECOCK POSITIION IN AIR(Z) metres', 'OUT_OF_COURT_SHOTS']]

data2
# Out:
#        SHOT_ID  HUMAN PLAYER POSITION (X) metres  \
# 18800        1                                 4
# 18801        1                                 4
# 18802        1                                 4
# 18803        1                                 4
# 18804        1                                 4
# ...        ...                               ...
# 72634      270                                 4
# 72635      270                                 4
# 72636      270                                 4
# 72637      270                                 4
# 72638      270                                 4
#
#        HUMAN PLAYER POSITION (Y) metres  \
# 18800                                 1
# 18801                                 1
# 18802                                 1
# 18803                                 1
# 18804                                 1
# ...                                 ...
# 72634                                 4
# 72635                                 4
# 72636                                 4
# 72637                                 4
# 72638                                 4
#
#        INITITAL VELOCITY OF SHUTTELCOCK(m/s)  \
# 18800                                     10
# 18801                                     10
# 18802                                     10
# 18803                                     10
# 18804                                     10
# ...                                      ...
# 72634                                     70
# 72635                                     70
# 72636                                     70
# 72637                                     70
# 72638                                     70
#
#        INITIAL SHUTTELCOCK FIRING ANGLE (DEGREE)  \
# 18800                                         60
# 18801                                         60
# 18802                                         60
# 18803                                         60
# 18804                                         60
# ...                                          ...
# 72634                                         70
# 72635                                         70
# 72636                                         70
# 72637                                         70
# 72638                                         70
#
#        SHUTTELCOCK SLANT ANGLE TO SIDELINE(DEGREE)  \
# 18800                                            0
# 18801                                            0
# 18802                                            0
# 18803                                            0
# 18804                                            0
# ...                                            ...
# 72634                                           15
# 72635                                           15
# 72636                                           15
# 72637                                           15
# 72638                                           15
#
#        SHUTTLECOCK POSITIION IN AIR(X ) metres  \
# 18800                                 4.049659
# 18801                                 4.100141
# 18802                                 4.147209
# 18803                                 4.197915
# 18804                                 4.246229
# ...                                        ...
# 72634                                 9.217823
# 72635                                 9.275177
# 72636                                 9.326363
# 72637                                 9.370879
# 72638                                 9.412822
#
#        SHUTTLECOCK POSITIION IN AIR(Y) metres  \
# 18800                                1.000000
# 18801                                1.000000
# 18802                                1.000000
# 18803                                1.000000
# 18804                                1.000000
# ...                                       ...
# 72634                                5.398111
# 72635                                5.413480
# 72636                                5.427195
# 72637                                5.439123
# 72638                                5.450361
#
#        SHUTTLECOCK POSITIION IN AIR(Z) metres  OUT_OF_COURT_SHOTS
# 18800                                1.685961                   1
# 18801                                1.770894                   1
# 18802                                1.852351                   1
# 18803                                1.935086                   1
# 18804                                2.013513                   1
# ...                                       ...                 ...
# 72634                                2.591053                   0
# 72635                                2.041410                   0
# 72636                                1.463594                   0
# 72637                                0.862842                   0
# 72638                                0.230964                   0
#
# [27690 rows x 10 columns]

# %%
data2.to_csv("badmintondata1_cleaned_data.csv", index=False)
